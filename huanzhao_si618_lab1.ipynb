# %% [markdown]
# Let's start by important the appropriate libraries.

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# *This is a markdown example*

# %% [markdown]
# <font color='red'>To-do:</font> Insert a cell in markdown mode and write "This is a markdown example" in italics.

# %% [markdown]
# ### Initialization
# You can create a Series by passing a list of values. By default, pandas will create an integer index.

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# Let's create another Series

# %%
s3 = pd.Series(["a", "b", "c", "d"])
s3
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
s2 = pd.Series(["1", "10", "3", "44"])

# %%
s4 = s2.astype(int)
s4
# Out:
# 0     1
# 1    10
# 2     3
# 3    44
# dtype: int32

# %% [markdown]
# <font color='red'>To-do:</font> Insert a new cell above this one and create a new series called s3. You can choose its datatype, size, and elements. Display the result.

# %% [markdown]
# <font color='red'>To-do:</font> If you aim to store integers, string is an inefficient data type. Let's convert this series to the appropriate data type and store the result in s4. Display s4.

# %%
s3 = s2.astype(int) 
s3
# Out:
# 0     1
# 1    10
# 2     3
# 3    44
# dtype: int64

# %% [markdown]
# You can also use pandas to create an series of datetime objects. Let’s make one for the week beginning January 25th, 2015:

# %%
dates = pd.date_range('20150125',periods=7)
dates
# Out:
# DatetimeIndex(['2015-01-25', '2015-01-26', '2015-01-27', '2015-01-28',
#                '2015-01-29', '2015-01-30', '2015-01-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates2 = pd.date_range('20190903','20190906',periods=3)
dates2
# Out:
# DatetimeIndex(['2019-09-03 00:00:00', '2019-09-04 12:00:00',
#                '2019-09-06 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# <font color='red'>To-do:</font> Insert a new cell below this one and create a new dates2 DatetimeIndex object that starts September 3, 2019, ends with September 6, 2019 and has three periods. Display the result.

# %% [markdown]
# Now we’ll create a DataFrame using the dates array as our index, fill it with some random values using numpy, and give the columns some labels.

# %%
df = pd.DataFrame(np.random.randn(7,4), index=dates, columns=['col1','col2','col4','col3'])
df
# Out:
#                 col1      col2      col4      col3
# 2015-01-25 -1.893340  0.096575  1.337967 -0.979166
# 2015-01-26 -1.167749 -0.656836 -0.680043 -1.180949
# 2015-01-27  0.392207 -0.668079  1.360885 -1.722293
# 2015-01-28  1.123299 -0.210230  0.047026 -1.198196
# 2015-01-29 -1.125114  0.772614 -0.707897  1.037581
# 2015-01-30 -1.273810 -0.775360 -2.823397  0.310565
# 2015-01-31  1.611109  1.938306 -1.412439 -0.436582

# %% [markdown]
# <font color='red'>To-do:</font> Now create df2 that uses dates2 as its index. Use the same set of columns ('col1','col2','col4','col3').

# %%
df2 = pd.DataFrame(np.random.randn(3,4), index=dates2, columns=['col1','col2','col4','col3'])
df2
# Out:
#                          col1      col2      col4      col3
# 2019-09-03 00:00:00 -0.690720 -1.376066 -1.419988 -0.024142
# 2019-09-04 12:00:00 -1.135891  0.616027  1.254048  1.378692
# 2019-09-06 00:00:00 -1.596803 -1.026206  0.176984 -0.265224

# %% [markdown]
# It can also be useful to know how to create a DataFrame from a dict of objects. This comes in particularly handy when working with JSON-like structures.

# %%
df3 = pd.DataFrame({ 'A' : 1.,
                            'B' : pd.Timestamp('20130102'),
                            'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                            'D' : np.array([3] * 4,dtype='int32'),
                            'E' : pd.Categorical(["test","train","test","train"]),
                            'F' : 'foo' })
df3
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %% [markdown]
# <font color='red'>To-do:</font> Below we are trying to create another DataFrame df4. But there are some mistakes. Correct these mistakes to make sure the code compiles. Do not edit column c2.

# %%
df4 = pd.DataFrame({ "c1" : 1,
                       "c2": [1,3,3,"book"],
                       "c3": [True,False,True,np.nan]})

# %% [markdown]
# <font color='red'>To-do:</font> Print out the datatypes of columns in df4.

# %%
df4
# Out:
#    c1    c2     c3
# 0   1     1   True
# 1   1     3  False
# 2   1     3   True
# 3   1  book    NaN

# %% [markdown]
# What do you see for c2? You can see that pandas tries to find a common object type. This is great but this flexibility can also result in runtime errors.  Make sure you are careful with the use of data types.

# %% [markdown]
# ### Exploring data in a DataFrame
# We can access the data types of each column in a DataFrame as follows:

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-25', '2015-01-26', '2015-01-27', '2015-01-28',
#                '2015-01-29', '2015-01-30', '2015-01-31'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# A few other basic operations:

# %%
df.values
# Out:
# array([[-1.56525751,  0.47884924,  0.43971897,  0.24117685],
#        [-1.15701686,  1.20866065, -0.44485132, -0.08569942],
#        [-0.95318202,  0.69626462,  2.05079672,  0.72093192],
#        [ 1.34843118, -0.47707926, -0.62030739,  0.37340474],
#        [-0.98605809, -0.82101997,  0.06792945,  0.72206496],
#        [-0.77213966, -0.11765859, -2.20098501, -0.72340018],
#        [ 0.95935785,  0.70179348, -1.60533725, -0.61658203]])

# %%
df.describe()
# Out:
#            col1      col2      col4      col3
# count  7.000000  7.000000  7.000000  7.000000
# mean  -0.446552  0.238544 -0.330434  0.090271
# std    1.126096  0.728544  1.393051  0.590551
# min   -1.565258 -0.821020 -2.200985 -0.723400
# 25%   -1.071537 -0.297369 -1.112822 -0.351141
# 50%   -0.953182  0.478849 -0.444851  0.241177
# 75%    0.093609  0.699029  0.253824  0.547168
# max    1.348431  1.208661  2.050797  0.722065

# %% [markdown]
# <font color='red'>To-do:</font> Print the column names for df.

# %%
list(df)
# Out:
# ['col1', 'col2', 'col4', 'col3']

# %% [markdown]
# ### Some basic data transformations
# DataFrames have a built-in transpose

# %%
df.T
# Out:
#       2015-01-25  2015-01-26  2015-01-27  2015-01-28  2015-01-29  2015-01-30  \
# col1   -1.565258   -1.157017   -0.953182    1.348431   -0.986058   -0.772140
# col2    0.478849    1.208661    0.696265   -0.477079   -0.821020   -0.117659
# col4    0.439719   -0.444851    2.050797   -0.620307    0.067929   -2.200985
# col3    0.241177   -0.085699    0.720932    0.373405    0.722065   -0.723400
#
#       2015-01-31
# col1    0.959358
# col2    0.701793
# col4   -1.605337
# col3   -0.616582

# %% [markdown]
# We can also sort a DataFrame along a given data dimension. For example, we might want to sort by the values in the second column:

# %%
df.sort_values(by=['col2'])
# Out:
#                 col1      col2      col4      col3
# 2015-01-29 -0.986058 -0.821020  0.067929  0.722065
# 2015-01-28  1.348431 -0.477079 -0.620307  0.373405
# 2015-01-30 -0.772140 -0.117659 -2.200985 -0.723400
# 2015-01-25 -1.565258  0.478849  0.439719  0.241177
# 2015-01-27 -0.953182  0.696265  2.050797  0.720932
# 2015-01-31  0.959358  0.701793 -1.605337 -0.616582
# 2015-01-26 -1.157017  1.208661 -0.444851 -0.085699

# %% [markdown]
# We can also sort the rows (axis = 0) by their index values:

# %%
df.sort_index(axis=0, ascending=False)
# Out:
#                 col1      col2      col4      col3
# 2015-01-31  0.959358  0.701793 -1.605337 -0.616582
# 2015-01-30 -0.772140 -0.117659 -2.200985 -0.723400
# 2015-01-29 -0.986058 -0.821020  0.067929  0.722065
# 2015-01-28  1.348431 -0.477079 -0.620307  0.373405
# 2015-01-27 -0.953182  0.696265  2.050797  0.720932
# 2015-01-26 -1.157017  1.208661 -0.444851 -0.085699
# 2015-01-25 -1.565258  0.478849  0.439719  0.241177

# %% [markdown]
# <font color='red'>To-do:</font> Sort df according to column header values using df.sort_index.

# %%
df.sort_index(axis=1)
# Out:
#                 col1      col2      col3      col4
# 2015-01-25 -0.681970 -1.727048 -0.231674  0.249864
# 2015-01-26 -1.383030  1.967102  0.304506 -1.307741
# 2015-01-27  0.375892 -1.222908 -0.370616  0.092021
# 2015-01-28  0.946441 -0.750997 -0.208877  0.283238
# 2015-01-29  0.794870  0.051159  0.496139 -0.530766
# 2015-01-30 -0.089873  1.891574 -1.039678  0.788879
# 2015-01-31 -0.176489 -1.007983 -0.982334 -0.065618

# %% [markdown]
# ### Selection
# To select only only the first few rows of a DataFrame, use the .head() function, or tail to get the last few rows. These functions by default return 5 rows but you can change that.

# %%
df.head()
# Out:
#                 col1      col2      col4      col3
# 2015-01-25 -1.565258  0.478849  0.439719  0.241177
# 2015-01-26 -1.157017  1.208661 -0.444851 -0.085699
# 2015-01-27 -0.953182  0.696265  2.050797  0.720932
# 2015-01-28  1.348431 -0.477079 -0.620307  0.373405
# 2015-01-29 -0.986058 -0.821020  0.067929  0.722065

# %% [markdown]
# <font color='red'>To-do:</font> Get the last 3 rows in df.

# %%
df.tail(3)
# Out:
#                 col1      col2      col4      col3
# 2015-01-29  0.794870  0.051159 -0.530766  0.496139
# 2015-01-30 -0.089873  1.891574  0.788879 -1.039678
# 2015-01-31 -0.176489 -1.007983 -0.065618 -0.982334

# %% [markdown]
# Selecting a single column yields a Series, equivalent to df.col1:

# %%
df['col1']
# Out:
# 2015-01-25   -1.565258
# 2015-01-26   -1.157017
# 2015-01-27   -0.953182
# 2015-01-28    1.348431
# 2015-01-29   -0.986058
# 2015-01-30   -0.772140
# 2015-01-31    0.959358
# Freq: D, Name: col1, dtype: float64

# %% [markdown]
# We can also select a subset of the rows using slicing. You can select either by integer indexing or by value:

# %%
df[1:3]
# Out:
#                 col1      col2      col4      col3
# 2015-01-26 -1.157017  1.208661 -0.444851 -0.085699
# 2015-01-27 -0.953182  0.696265  2.050797  0.720932

# %%
df['20150127':'20150130']
# Out:
#                 col1      col2      col4      col3
# 2015-01-27 -0.953182  0.696265  2.050797  0.720932
# 2015-01-28  1.348431 -0.477079 -0.620307  0.373405
# 2015-01-29 -0.986058 -0.821020  0.067929  0.722065
# 2015-01-30 -0.772140 -0.117659 -2.200985 -0.723400

# %% [markdown]
# To select more than one column at a time, try .loc[]):

# %%
df.loc[:,['col2','col4']]
# Out:
#                 col2      col4
# 2015-01-25 -1.594279 -0.776911
# 2015-01-26  0.615758 -0.291804
# 2015-01-27 -0.511680 -1.397961
# 2015-01-28  1.261545 -0.757780
# 2015-01-29 -0.190971 -1.277846
# 2015-01-30 -0.485837  1.312922
# 2015-01-31 -0.158546  1.373486

# %% [markdown]
# You can select on rows and columns at the same time:

# %% [markdown]
# <font color='red'>To-do:</font> You can select on rows and columns at the same time. Select rows from '20150127' through '20150130' and columns col2 and col4.

# %%
df.loc['20150127':'20150130',['col2','col4']]
# Out:
#                 col2      col4
# 2015-01-27 -0.511680 -1.397961
# 2015-01-28  1.261545 -0.757780
# 2015-01-29 -0.190971 -1.277846
# 2015-01-30 -0.485837  1.312922

# %% [markdown]
# You can also use boolean indexing to select subset of a dataframe that satisfies a requirement

# %%
df[df['col1'] > 0]
# Out:
#                 col1      col2      col4      col3
# 2015-01-27  0.392207 -0.668079  1.360885 -1.722293
# 2015-01-28  1.123299 -0.210230  0.047026 -1.198196
# 2015-01-31  1.611109  1.938306 -1.412439 -0.436582

# %% [markdown]
# <font color='red'>To-do:</font> Now select the rows where both col1 and col4 are greater than zero.

# %%
df[(df['col1'] > 0) & (df['col4'] > 0)]
# Out:
#                 col1      col2      col4      col3
# 2015-01-27  0.392207 -0.668079  1.360885 -1.722293
# 2015-01-28  1.123299 -0.210230  0.047026 -1.198196

# %%
nonneg_only = df[df > 0]

# %%
nonneg_only
# Out:
#                 col1      col2      col4      col3
# 2015-01-25       NaN  0.478849  0.439719  0.241177
# 2015-01-26       NaN  1.208661       NaN       NaN
# 2015-01-27       NaN  0.696265  2.050797  0.720932
# 2015-01-28  1.348431       NaN       NaN  0.373405
# 2015-01-29       NaN       NaN  0.067929  0.722065
# 2015-01-30       NaN       NaN       NaN       NaN
# 2015-01-31  0.959358  0.701793       NaN       NaN

# %% [markdown]
# You can drop rows with missing values as such:

# %%
nonneg_only.dropna()
# Out:
# Empty DataFrame
# Columns: [col1, col2, col4, col3]
# Index: []

# %% [markdown]
# There were no rows with no missing values (most likely, these are random numbers after all...) and therefore the result is an empty dataframe. You can instead assign a default value (here, 0) to the NaN values

# %%
nonneg_only.fillna(value=0)
# Out:
#                 col1      col2      col4      col3
# 2015-01-25  0.000000  0.478849  0.439719  0.241177
# 2015-01-26  0.000000  1.208661  0.000000  0.000000
# 2015-01-27  0.000000  0.696265  2.050797  0.720932
# 2015-01-28  1.348431  0.000000  0.000000  0.373405
# 2015-01-29  0.000000  0.000000  0.067929  0.722065
# 2015-01-30  0.000000  0.000000  0.000000  0.000000
# 2015-01-31  0.959358  0.701793  0.000000  0.000000

# %% [markdown]
# You can also do filtering using non-numeric values:

# %%
df_c = df.copy()
df_c['color'] = ['red', 'blue', 'red', 'red', 'blue', 'green', 'green' ]
df_c
# Out:
#                 col1      col2      col4      col3  color
# 2015-01-25 -1.565258  0.478849  0.439719  0.241177    red
# 2015-01-26 -1.157017  1.208661 -0.444851 -0.085699   blue
# 2015-01-27 -0.953182  0.696265  2.050797  0.720932    red
# 2015-01-28  1.348431 -0.477079 -0.620307  0.373405    red
# 2015-01-29 -0.986058 -0.821020  0.067929  0.722065   blue
# 2015-01-30 -0.772140 -0.117659 -2.200985 -0.723400  green
# 2015-01-31  0.959358  0.701793 -1.605337 -0.616582  green

# %%
df_c[df_c['color'].isin(['red','blue'])]
# Out:
#                 col1      col2      col4      col3 color
# 2015-01-25 -1.565258  0.478849  0.439719  0.241177   red
# 2015-01-26 -1.157017  1.208661 -0.444851 -0.085699  blue
# 2015-01-27 -0.953182  0.696265  2.050797  0.720932   red
# 2015-01-28  1.348431 -0.477079 -0.620307  0.373405   red
# 2015-01-29 -0.986058 -0.821020  0.067929  0.722065  blue

# %% [markdown]
# ### Combining DataFrames
# You can combine DataFrame objects using simple concatenation (provided they have the same columns):

# %%
frame_one = pd.DataFrame(np.random.randn(5, 4))
frame_one
# Out:
#           0         1         2         3
# 0 -0.797748  0.611962 -0.122684  0.532456
# 1 -2.064270  1.214046  0.365193  2.172883
# 2  0.172033  1.037819 -0.123083 -0.288450
# 3  0.347701 -1.905529 -0.971855  1.540174
# 4 -1.279071 -0.266552  1.097745 -0.482095

# %%
frame_two = pd.DataFrame(np.random.randn(5, 4))
frame_two
# Out:
#           0         1         2         3
# 0  0.694541 -0.733790  0.651363 -1.610668
# 1  0.261796  0.836095 -0.804964 -0.658426
# 2 -0.210961 -1.195197  0.291604  0.816031
# 3 -1.950912 -0.165943 -0.154534 -0.039707
# 4 -0.393451  0.514158  0.648017 -0.559643

# %%
pd.concat([frame_one, frame_two])
# Out:
#           0         1         2         3
# 0 -0.797748  0.611962 -0.122684  0.532456
# 1 -2.064270  1.214046  0.365193  2.172883
# 2  0.172033  1.037819 -0.123083 -0.288450
# 3  0.347701 -1.905529 -0.971855  1.540174
# 4 -1.279071 -0.266552  1.097745 -0.482095
# 0  0.694541 -0.733790  0.651363 -1.610668
# 1  0.261796  0.836095 -0.804964 -0.658426
# 2 -0.210961 -1.195197  0.291604  0.816031
# 3 -1.950912 -0.165943 -0.154534 -0.039707
# 4 -0.393451  0.514158  0.648017 -0.559643

# %% [markdown]
# <font color='red'>To-do:</font> Now concatenate along the other axis.

# %%
pd.concat([frame_one, frame_two],axis = 1)
# Out:
#           0         1         2         3         0         1         2  \
# 0 -0.797748  0.611962 -0.122684  0.532456  0.694541 -0.733790  0.651363
# 1 -2.064270  1.214046  0.365193  2.172883  0.261796  0.836095 -0.804964
# 2  0.172033  1.037819 -0.123083 -0.288450 -0.210961 -1.195197  0.291604
# 3  0.347701 -1.905529 -0.971855  1.540174 -1.950912 -0.165943 -0.154534
# 4 -1.279071 -0.266552  1.097745 -0.482095 -0.393451  0.514158  0.648017
#
#           3
# 0 -1.610668
# 1 -0.658426
# 2  0.816031
# 3 -0.039707
# 4 -0.559643

# %% [markdown]
# <font color='red'>To-do:</font> Do you see an issue here? What do you think we need to do to avoid this problem?

# %% [markdown]
# The issue here is that the index of column names has duplicates. We can write pd.concat([frame_one, frame_two],axis = 1,ignore_index = True)

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right = pd.DataFrame({'key': ['foo', 'foo', 'bar'], 'rval': [3, 4, 5]}) 
right
# Out:
#    key  rval
# 0  foo     3
# 1  foo     4
# 2  bar     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     3
# 1  foo     1     4
# 2  bar     2     5

# %% [markdown]
# ### Grouping
# Sometimes you will want to group and summarize a DataFrame for a more efficient computation. This is one of the strengths of pandas and DataFrames.

# %%
foo_bar = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar','foo', 'bar', 'foo', 'foo'],
                                   'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                                   'C' : np.random.randn(8),
                                   'D' : np.random.randn(8)})
foo_bar
# Out:
#      A      B         C         D
# 0  foo    one -0.324567 -0.240485
# 1  bar    one -0.715098 -0.211983
# 2  foo    two -1.601050  0.612110
# 3  bar  three  1.192517  0.205858
# 4  foo    two -0.253847 -0.335603
# 5  bar    two  1.679310  0.515568
# 6  foo    one  0.791337 -0.112544
# 7  foo  three -1.142499 -0.714091

# %%
grouped = foo_bar.groupby('A').sum()

# %% [markdown]
# <font color='red'>To-do:</font> What happened to column B? Because sum oepration cannot be applied to datatype string, the column was dropped here. Now use both columns to perform the operation for each possible A, B pair. Assin this to "grouped" and display it.

# %%
grouped = foo_bar.groupby(['A','B']).size()
grouped
# Out:
# A    B
# bar  one      1
#      three    1
#      two      1
# foo  one      2
#      three    1
#      two      2
# dtype: int64

# %% [markdown]
# The .stack() function can be used to compress a level in the DataFrame’s columns:

# %%
stacked = grouped.stack()
stacked
# Out:
# A
# bar  C    1.269333
#      D   -1.700906
# foo  C   -0.324141
#      D   -4.031255
# dtype: float64

# %%
stacked.unstack()
# Out:
#             C         D
# A
# bar  1.269333 -1.700906
# foo -0.324141 -4.031255

# %% [markdown]
# ## Reading from/Writing to files
# You can write a dataframe to file as follows:

# %%
grouped.to_csv('grouped.csv')

# %% [markdown]
# <font color='red'>To-do:</font> Now write this same DataFrame to a JSON file.

# %%
grouped.to_json('grouped.json')

# %% [markdown]
# And you can read as follows:

# %%
new_frame = pd.read_csv('grouped.csv')

# %%
new_frame.head()
# Out:
#      A         C         D
# 0  bar  1.269333 -1.700906
# 1  foo -0.324141 -4.031255

# %% [markdown]
# Let's now work with a relatively more complex and bigger file

# %%
comics_df = pd.read_csv('comic_characters.csv')
comics_df
# Out:
#           id publisher                                 name          Identity  \
# 0          1    Marvel            Spider-Man (Peter Parker)   Secret Identity
# 1          2    Marvel      Captain America (Steven Rogers)   Public Identity
# 2          3    Marvel  Wolverine (James \"Logan\" Howlett)   Public Identity
# 3          4    Marvel    Iron Man (Anthony \"Tony\" Stark)   Public Identity
# 4          5    Marvel                  Thor (Thor Odinson)  No Dual Identity
# 5          6    Marvel           Benjamin Grimm (Earth-616)   Public Identity
# 6          7    Marvel            Reed Richards (Earth-616)   Public Identity
# 7          8    Marvel           Hulk (Robert Bruce Banner)   Public Identity
# 8          9    Marvel            Scott Summers (Earth-616)   Public Identity
# 9         10    Marvel           Jonathan Storm (Earth-616)   Public Identity
# 10        11    Marvel              Henry McCoy (Earth-616)   Public Identity
# 11        12    Marvel              Susan Storm (Earth-616)   Public Identity
# 12        13    Marvel           Namor McKenzie (Earth-616)  No Dual Identity
# 13        14    Marvel             Ororo Munroe (Earth-616)   Public Identity
# 14        15    Marvel           Clinton Barton (Earth-616)   Public Identity
# 15        16    Marvel          Matthew Murdock (Earth-616)   Public Identity
# 16        17    Marvel          Stephen Strange (Earth-616)   Public Identity
# 17        18    Marvel         Mary Jane Watson (Earth-616)  No Dual Identity
# 18        19    Marvel       John Jonah Jameson (Earth-616)  No Dual Identity
# 19        20    Marvel             Robert Drake (Earth-616)   Secret Identity
# 20        21    Marvel                Henry Pym (Earth-616)   Public Identity
# 21        22    Marvel           Charles Xavier (Earth-616)   Public Identity
# 22        23    Marvel   Warren Worthington III (Earth-616)   Public Identity
# 23        24    Marvel           Piotr Rasputin (Earth-616)   Secret Identity
# 24        25    Marvel           Wanda Maximoff (Earth-616)   Public Identity
# 25        26    Marvel            Nicholas Fury (Earth-616)  No Dual Identity
# 26        27    Marvel           Janet van Dyne (Earth-616)   Public Identity
# 27        28    Marvel                Jean Grey (Earth-616)   Public Identity
# 28        29    Marvel         Natalia Romanova (Earth-616)   Public Identity
# 29        30    Marvel              Kurt Wagner (Earth-616)   Secret Identity
# ...      ...       ...                                  ...               ...
# 23242  23243        DC             Baron Tyrano (New Earth)   Secret Identity
# 23243  23244        DC                   Brains (New Earth)               NaN
# 23244  23245        DC                  Cracker (New Earth)               NaN
# 23245  23246        DC                Hard Head (New Earth)               NaN
# 23246  23247        DC                  Zig-Zag (New Earth)               NaN
# 23247  23248        DC                Dragonfly (New Earth)   Secret Identity
# 23248  23249        DC            Carl Bradford (New Earth)               NaN
# 23249  23250        DC               Donna Troy (New Earth)   Public Identity
# 23250  23251        DC        Bartholomew Magan (New Earth)               NaN
# 23251  23252        DC               James Moon (New Earth)               NaN
# 23252  23253        DC                   Flash (Wally West)   Secret Identity
# 23253  23254        DC             J'onn J'onzz (New Earth)   Public Identity
# 23254  23255        DC            Dorothea Tane (New Earth)               NaN
# 23255  23256        DC                    Dmane (Earth-Two)               NaN
# 23256  23257        DC      Maximillian O'Leary (New Earth)   Public Identity
# 23257  23258        DC               Doris Zuel (New Earth)   Secret Identity
# 23258  23259        DC                Doris Lee (New Earth)   Public Identity
# 23259  23260        DC          Patrick O'Brian (New Earth)   Secret Identity
# 23260  23261        DC              Basil Karlo (New Earth)   Secret Identity
# 23261  23262        DC               Catwoman (Selina Kyle)   Secret Identity
# 23244    Living Characters          NaN       1967, June       June  1967.0
# 23245    Living Characters          NaN      1967, April      April  1967.0
# 23246    Living Characters          NaN       1967, June       June  1967.0
# 23247    Living Characters          NaN       1966, June       June  1966.0
# 23248    Living Characters          NaN    1966, January    January  1966.0
# 23249    Living Characters          NaN       1965, July       July  1965.0
# 23250    Living Characters          NaN  1963, September  September  1963.0
# 23251    Living Characters          NaN      1962, March      March  1962.0
# 23252    Living Characters          NaN    1960, January    January  1960.0
# 23253    Living Characters          NaN   1955, November   November  1955.0
# 23254    Living Characters          NaN     1948, August     August  1948.0
# 23255    Living Characters          NaN      1946, April      April  1946.0
# 23256    Living Characters          NaN    1946, January    January  1946.0
# 23257    Living Characters          NaN       1944, June       June  1944.0
# 23258  Deceased Characters          NaN      1941, April      April  1941.0
# 23259    Living Characters          NaN     1941, August     August  1941.0
# 23260    Living Characters          NaN       1940, June       June  1940.0
# 23261    Living Characters          NaN       1940, June       June  1940.0
# 23262    Living Characters          NaN   1936, February   February  1936.0
# 23263    Living Characters          NaN              NaN          1     NaN
# 23264    Living Characters          NaN              NaN          1     NaN
# 23265    Living Characters          NaN              NaN          1     NaN
# 23266    Living Characters          NaN              NaN          1     NaN
# 23267    Living Characters          NaN              NaN          1     NaN
# 23268    Living Characters          NaN              NaN          1     NaN
# 23269    Living Characters          NaN              NaN          1     NaN
# 23270    Living Characters          NaN              NaN          1     NaN
# 23271    Living Characters          NaN              NaN          1     NaN
#
#             date
# 0       8/1/1962
# 1       3/1/1941
# 2      10/1/1974
# 3       3/1/1963
# 4      11/1/1950
# 5      11/1/1961
# 6      11/1/1961
# 7       5/1/1962
# 8       9/1/1963
# 9      11/1/1961
# 10      9/1/1963
# 11     11/1/1961
# 12           NaN
# 13      5/1/1975
# 14      9/1/1964
# 15      4/1/1964
# 16      7/1/1963
# 17      6/1/1965
# 18      3/1/1963
# 19      9/1/1963
# 20      1/1/1962
# 21      9/1/1963
# 22      9/1/1963
# 23      5/1/1975
# 24      3/1/1964
# 25      5/1/1963
# 26      6/1/1963
# 27      9/1/1963
# 28      4/1/1964
# 29      5/1/1975
# ...          ...
# 23242   7/1/1967
# 23243   4/1/1967
# 23244   6/1/1967
# 23245   4/1/1967
# 23246   6/1/1967
# 23247   6/1/1966
# 23248   1/1/1966
# 23249   7/1/1965
# 23250   9/1/1963
# 23251   3/1/1962
# 23252   1/1/1960
# 23253  11/1/1955
# 23254   8/1/1948
# 23255   4/1/1946
# 23256   1/1/1946
# 23257   6/1/1944
# 23258   4/1/1941
# 23259   8/1/1941
# 23260   6/1/1940
# 23261   6/1/1940
# 23262   2/1/1936
# 23263        NaN
# 23264        NaN
# 23265        NaN
# 23266        NaN
# 23267        NaN
# 23268        NaN
# 23269        NaN
# 23270        NaN
# 23271        NaN
#
# [23272 rows x 14 columns]

# %%
comic_df = pd.read_csv('comic_characters.csv',
parse_dates=['date'], dayfirst=False, index_col='id')
comic_df
# Out:
#       publisher                                 name          Identity  \
# id
# 1        Marvel            Spider-Man (Peter Parker)   Secret Identity
# 2        Marvel      Captain America (Steven Rogers)   Public Identity
# 3        Marvel  Wolverine (James \"Logan\" Howlett)   Public Identity
# 4        Marvel    Iron Man (Anthony \"Tony\" Stark)   Public Identity
# 5        Marvel                  Thor (Thor Odinson)  No Dual Identity
# 6        Marvel           Benjamin Grimm (Earth-616)   Public Identity
# 7        Marvel            Reed Richards (Earth-616)   Public Identity
# 8        Marvel           Hulk (Robert Bruce Banner)   Public Identity
# 9        Marvel            Scott Summers (Earth-616)   Public Identity
# 10       Marvel           Jonathan Storm (Earth-616)   Public Identity
# 11       Marvel              Henry McCoy (Earth-616)   Public Identity
# 12       Marvel              Susan Storm (Earth-616)   Public Identity
# 13       Marvel           Namor McKenzie (Earth-616)  No Dual Identity
# 14       Marvel             Ororo Munroe (Earth-616)   Public Identity
# 15       Marvel           Clinton Barton (Earth-616)   Public Identity
# 16       Marvel          Matthew Murdock (Earth-616)   Public Identity
# 17       Marvel          Stephen Strange (Earth-616)   Public Identity
# 18       Marvel         Mary Jane Watson (Earth-616)  No Dual Identity
# 19       Marvel       John Jonah Jameson (Earth-616)  No Dual Identity
# 20       Marvel             Robert Drake (Earth-616)   Secret Identity
# 21       Marvel                Henry Pym (Earth-616)   Public Identity
# 22       Marvel           Charles Xavier (Earth-616)   Public Identity
# 23       Marvel   Warren Worthington III (Earth-616)   Public Identity
# 24       Marvel           Piotr Rasputin (Earth-616)   Secret Identity
# 25       Marvel           Wanda Maximoff (Earth-616)   Public Identity
# 26       Marvel            Nicholas Fury (Earth-616)  No Dual Identity
# 27       Marvel           Janet van Dyne (Earth-616)   Public Identity
# 28       Marvel                Jean Grey (Earth-616)   Public Identity
# 29       Marvel         Natalia Romanova (Earth-616)   Public Identity
# 30       Marvel              Kurt Wagner (Earth-616)   Secret Identity
# ...         ...                                  ...               ...
# 23243        DC             Baron Tyrano (New Earth)   Secret Identity
# 23244        DC                   Brains (New Earth)               NaN
# 23245        DC                  Cracker (New Earth)               NaN
# 23246        DC                Hard Head (New Earth)               NaN
# 23247        DC                  Zig-Zag (New Earth)               NaN
# 23248        DC                Dragonfly (New Earth)   Secret Identity
# 23249        DC            Carl Bradford (New Earth)               NaN
# 23250        DC               Donna Troy (New Earth)   Public Identity
# 23251        DC        Bartholomew Magan (New Earth)               NaN
# 23252        DC               James Moon (New Earth)               NaN
# 23253        DC                   Flash (Wally West)   Secret Identity
# 23254        DC             J'onn J'onzz (New Earth)   Public Identity
# 23255        DC            Dorothea Tane (New Earth)               NaN
# 23256        DC                    Dmane (Earth-Two)               NaN
# 23257        DC      Maximillian O'Leary (New Earth)   Public Identity
# 23258        DC               Doris Zuel (New Earth)   Secret Identity
# 23259        DC                Doris Lee (New Earth)   Public Identity
# 23260        DC          Patrick O'Brian (New Earth)   Secret Identity
# 23261        DC              Basil Karlo (New Earth)   Secret Identity
# 23262        DC               Catwoman (Selina Kyle)   Secret Identity
# 23263        DC                 Bedivere (New Earth)               NaN
# 23264        DC           Herbert Hoover (New Earth)   Public Identity
# 23265        DC      William Howard Taft (New Earth)   Public Identity
# 23266        DC        Frank Fitzsimmons (New Earth)   Public Identity
# 23267        DC           James Garfield (New Earth)   Public Identity
# 23268        DC              Nadine West (New Earth)   Public Identity
# 23269        DC           Warren Harding (New Earth)   Public Identity
# 23270        DC         William Harrison (New Earth)   Public Identity
# 23271        DC         William McKinley (New Earth)   Public Identity
# 23272        DC                   Mookie (New Earth)   Public Identity
#
#                     align          eye         hair                sex  \
# id
# 1         Good Characters   Hazel Eyes   Brown Hair    Male Characters
# 2         Good Characters    Blue Eyes   White Hair    Male Characters
# 3      Neutral Characters    Blue Eyes   Black Hair    Male Characters
# 4         Good Characters    Blue Eyes   Black Hair    Male Characters
# 5         Good Characters    Blue Eyes   Blond Hair    Male Characters
# 6         Good Characters    Blue Eyes      No Hair    Male Characters
# 7         Good Characters   Brown Eyes   Brown Hair    Male Characters
# 8         Good Characters   Brown Eyes   Brown Hair    Male Characters
# 9      Neutral Characters   Brown Eyes   Brown Hair    Male Characters
# 10        Good Characters    Blue Eyes   Blond Hair    Male Characters
# 11        Good Characters    Blue Eyes    Blue Hair    Male Characters
# 12        Good Characters    Blue Eyes   Blond Hair  Female Characters
# 13     Neutral Characters   Green Eyes   Black Hair    Male Characters
# 14        Good Characters    Blue Eyes   White Hair  Female Characters
# 15        Good Characters    Blue Eyes   Blond Hair    Male Characters
# 16        Good Characters    Blue Eyes     Red Hair    Male Characters
# 17        Good Characters    Grey Eyes   Black Hair    Male Characters
# 18        Good Characters   Green Eyes     Red Hair  Female Characters
# 19     Neutral Characters    Blue Eyes   Black Hair    Male Characters
# 20        Good Characters   Brown Eyes   Brown Hair    Male Characters
# 21        Good Characters    Blue Eyes   Blond Hair    Male Characters
# 22        Good Characters    Blue Eyes         Bald    Male Characters
# 23        Good Characters    Blue Eyes   Blond Hair    Male Characters
# 24        Good Characters    Blue Eyes   Black Hair    Male Characters
# 25        Good Characters   Green Eyes   Brown Hair  Female Characters
# 26     Neutral Characters   Brown Eyes   Brown Hair    Male Characters
# 27        Good Characters    Blue Eyes  Auburn Hair  Female Characters
# 28        Good Characters   Green Eyes     Red Hair  Female Characters
# 29        Good Characters   Green Eyes     Red Hair  Female Characters
# 30        Good Characters  Yellow Eyes    Blue Hair    Male Characters
# ...                   ...          ...          ...                ...
# 23243      Bad Characters    Blue Eyes          NaN    Male Characters
# 23244     Good Characters          NaN          NaN    Male Characters
# 23245     Good Characters          NaN          NaN    Male Characters
# 23246     Good Characters          NaN   Black Hair    Male Characters
# 23247     Good Characters          NaN          NaN    Male Characters
# 23248      Bad Characters          NaN   Black Hair  Female Characters
# 23249      Bad Characters          NaN          NaN    Male Characters
# 23250     Good Characters    Blue Eyes   Black Hair  Female Characters
# 23251      Bad Characters          NaN          NaN    Male Characters
# 23252                 NaN          NaN          NaN    Male Characters
# 23253     Good Characters   Green Eyes     Red Hair    Male Characters
# 23247    Living Characters          NaN       1967, June       June  1967.0
# 23248    Living Characters          NaN       1966, June       June  1966.0
# 23249    Living Characters          NaN    1966, January    January  1966.0
# 23250    Living Characters          NaN       1965, July       July  1965.0
# 23251    Living Characters          NaN  1963, September  September  1963.0
# 23252    Living Characters          NaN      1962, March      March  1962.0
# 23253    Living Characters          NaN    1960, January    January  1960.0
# 23254    Living Characters          NaN   1955, November   November  1955.0
# 23255    Living Characters          NaN     1948, August     August  1948.0
# 23256    Living Characters          NaN      1946, April      April  1946.0
# 23257    Living Characters          NaN    1946, January    January  1946.0
# 23258    Living Characters          NaN       1944, June       June  1944.0
# 23259  Deceased Characters          NaN      1941, April      April  1941.0
# 23260    Living Characters          NaN     1941, August     August  1941.0
# 23261    Living Characters          NaN       1940, June       June  1940.0
# 23262    Living Characters          NaN       1940, June       June  1940.0
# 23263    Living Characters          NaN   1936, February   February  1936.0
# 23264    Living Characters          NaN              NaN          1     NaN
# 23265    Living Characters          NaN              NaN          1     NaN
# 23266    Living Characters          NaN              NaN          1     NaN
# 23267    Living Characters          NaN              NaN          1     NaN
# 23268    Living Characters          NaN              NaN          1     NaN
# 23269    Living Characters          NaN              NaN          1     NaN
# 23270    Living Characters          NaN              NaN          1     NaN
# 23271    Living Characters          NaN              NaN          1     NaN
# 23272    Living Characters          NaN              NaN          1     NaN
#
#             date
# id
# 1     1962-08-01
# 2     1941-03-01
# 3     1974-10-01
# 4     1963-03-01
# 5     1950-11-01
# 6     1961-11-01
# 7     1961-11-01
# 8     1962-05-01
# 9     1963-09-01
# 10    1961-11-01
# 11    1963-09-01
# 12    1961-11-01
# 13           NaT
# 14    1975-05-01
# 15    1964-09-01
# 16    1964-04-01
# 17    1963-07-01
# 18    1965-06-01
# 19    1963-03-01
# 20    1963-09-01
# 21    1962-01-01
# 22    1963-09-01
# 23    1963-09-01
# 24    1975-05-01
# 25    1964-03-01
# 26    1963-05-01
# 27    1963-06-01
# 28    1963-09-01
# 29    1964-04-01
# 30    1975-05-01
# ...          ...
# 23243 1967-07-01
# 23244 1967-04-01
# 23245 1967-06-01
# 23246 1967-04-01
# 23247 1967-06-01
# 23248 1966-06-01
# 23249 1966-01-01
# 23250 1965-07-01
# 23251 1963-09-01
# 23252 1962-03-01
# 23253 1960-01-01
# 23254 1955-11-01
# 23255 1948-08-01
# 23256 1946-04-01
# 23257 1946-01-01
# 23258 1944-06-01
# 23259 1941-04-01
# 23260 1941-08-01
# 23261 1940-06-01
# 23262 1940-06-01
# 23263 1936-02-01
# 23264        NaT
# 23265        NaT
# 23266        NaT
# 23267        NaT
# 23268        NaT
# 23269        NaT
# 23270        NaT
# 23271        NaT
# 23272        NaT
#
# [23272 rows x 13 columns]

# %% [markdown]
# The goal of this lab was to provide a high level introduction to pandas. There is so much more to it. You can/should practice more. A few other functions you might want to look into are: value_counts(), plot.hist(), pivot_table() and df.apply()... Note that we will use R for most of our analysis/visualization tasks but that doesn't mean you can't learn more about Python/pandas.
